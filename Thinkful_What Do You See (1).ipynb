# %%
import matplotlib.pyplot as plt
from matplotlib import style
import numpy as np
import pandas as pd
from pandas import Series
import calendar
# %pylab inline
# %matplotlib inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
#Loading the data into a data frame.
df = pd.read_csv('AAPL.csv')
df.head()
# Out:
#          date     open     high      low    close     volume  \
# 0  2014-01-23  72.1029  72.9630  71.4298  72.9210  100978346
# 1  2014-01-24  72.6352  72.8476  71.4224  71.5955  108384437
# 2  2014-01-27  72.1199  72.7401  71.5535  72.1763  144219152
# 3  2014-01-28  66.7037  67.5219  65.8266  66.4074  266833581
# 4  2014-01-29  66.0731  66.5215  65.3743  65.6535  125942796
#
#    unadjustedVolume    change  changePercent     vwap       label  \
# 0          14425478  0.612284          0.847  72.3787  Jan 23, 14
# 1          15483491 -1.325500         -1.818  72.1868  Jan 24, 14
# 2          20602736  0.580818          0.811  70.6687  Jan 27, 14
# 3          38119083 -5.768900         -7.993  66.7869  Jan 28, 14
# 4          17991828 -0.753887         -1.135  65.8259  Jan 29, 14
#
#    changeOverTime
# 0        0.000000
# 1       -0.018177
# 2       -0.010212
# 3       -0.089324
# 4       -0.099663

# %%
#Detailed table displaying distribution information for each of the attributes. 
print(df.describe())
# Out:
#               open         high          low        close        volume  \
# count  1258.000000  1258.000000  1258.000000  1258.000000  1.258000e+03
# mean    127.605044   128.707824   126.487178   127.625776  4.247238e+07
# std      38.811649    39.171605    38.429746    38.798604  2.324392e+07
# min      64.923300    65.755800    64.709600    65.526600  1.147592e+07
# 25%      99.776250   100.404975    98.800775    99.570175  2.660238e+07
# 50%     114.809250   115.893300   114.164600   115.139550  3.652324e+07
# 75%     156.317725   157.603775   154.762400   156.210000  5.159212e+07
# max     229.977600   232.658200   228.981100   231.263100  2.668336e+08
#
#        unadjustedVolume       change  changePercent         vwap  \
# count      1.258000e+03  1258.000000    1258.000000  1258.000000
# mean       3.755733e+07     0.064381       0.071665   127.643928
# std        2.040726e+07     2.110969       1.541982    38.788716
# ...

# %%
plt.plot(df['change'])
plt.ylabel ('Percent Change')
plt.xlabel ('Trading Day Since IPO')
plt.title('Apple Stock Change Over Time')
plt.show()

# %%
plt.hist(df['change'], color='green')
plt.hist(df['changeOverTime'], color='blue')
plt.show()

# %%
fy_2019 = df[df['date'].str.contains('2019',na=False)]
print(fy_2019)
# Out:
#             date    open      high       low   close    volume  \
# 1244  2019-01-02  154.89  158.8500  154.2300  157.92  37039737
# 1245  2019-01-03  143.98  145.7200  142.0000  142.19  91312195
# 1246  2019-01-04  144.53  148.5499  143.8000  148.26  58607070
# 1247  2019-01-07  148.70  148.8300  145.9000  147.93  54777764
# 1248  2019-01-08  149.56  151.8200  148.5200  150.75  41025314
# 1249  2019-01-09  151.29  154.5300  149.6300  153.31  45099081
# 1250  2019-01-10  152.50  153.9700  150.8600  153.80  35780670
# 1251  2019-01-11  152.88  153.7000  151.5100  152.29  27023241
# 1252  2019-01-14  150.85  151.2700  149.2200  150.00  32439186
# 1253  2019-01-15  150.27  153.3900  150.0500  153.07  28710324
# 1254  2019-01-16  153.08  155.8800  153.0000  154.94  30569706
# 1255  2019-01-17  154.20  157.6600  153.2600  155.86  29821160
# 1256  2019-01-18  157.50  157.8800  155.9806  156.82  33751023
# 1257  2019-01-22  156.41  156.7300  152.6200  153.30  30393970
#
# ...

# %%
plt.plot(df['volume'])&(df['date'].str.contains('2018',na=False))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\ops.py in na_op(x, y)
#    1303         try:
# -> 1304             result = op(x, y)
#    1305         except TypeError:
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops.py in rand_(left, right)
#     148 def rand_(left, right):
# --> 149     return operator.and_(right, left)
#     150
#
# TypeError: unsupported operand type(s) for &: 'Line2D' and 'bool'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-54-eecc8be00ac7> in <module>
# ----> 1 plt.plot(df['volume'])&(df['date'].str.contains('2018',na=False))
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops.py in wrapper(self, other)
#    1358                       is_integer_dtype(np.asarray(other)) else fill_bool)
# ...

# %%
plt.boxplot(df['volume'])
plt.show()

# %%
trading_volume = df
trading_volume.loc[lambda df: trading_volume['close'] > 80, :]
# Out:
#             date      open      high       low     close     volume  \
# 82    2014-05-21   79.7055   80.0843   79.4719   80.0329   49249914
# 83    2014-05-22   80.0711   80.5001   79.7411   80.1596   50218945
# 84    2014-05-23   80.1569   81.1442   80.0540   81.0651   58052491
# 85    2014-05-27   81.2961   82.6134   81.2631   82.5831   87216605
# 86    2014-05-28   82.6346   83.1375   82.3389   82.3692   78921885
# 87    2014-05-29   82.8761   84.0668   82.8656   83.8701   94118633
# 88    2014-05-30   84.2133   85.0304   83.0147   83.5559  141005137
# 89    2014-06-02   83.6826   83.7975   82.1699   82.9817   92337903
# 90    2014-06-03   82.9566   84.3136   82.9289   84.1552   73231620
# 91    2014-06-04   84.1420   85.5214   83.9664   85.1162   83870521
# 92    2014-06-05   85.2983   85.7168   84.8244   85.4501   75951141
# 93    2014-06-06   85.7867   85.9662   85.0700   85.2152   87620911
# 94    2014-06-09   85.6548   86.7451   84.7769   86.5788   75414804
# ...
